# %%
import pandas as pd

# %%
# Series
series = pd.Series([10,20,30,40,50,60])
series
# Out:
# 0    10
# 1    20
# 2    30
# 3    40
# 4    50
# 5    60
# dtype: int64

# %%
type(series)
# Out:
# pandas.core.series.Series

# %%
series[3]
# Out:
# 40

# %%
cad = pd.Series(['p', 'l', 'a', 't', 'z', 'i'])
cad
# Out:
# 0    p
# 1    l
# 2    a
# 3    t
# 4    z
# 5    i
# dtype: object

# %%
# DataFrame
lista = ['Hola', 'mundo', 'robotico']
df = pd.DataFrame(lista)
print(df)
# Out:
#           0
# 0      Hola
# 1     mundo
# 2  robotico

# %%
# Crear un dataframe a partir de un diccionario
data = {'Nombre': ['Miguel', 'Paty', 'Cesar', 'Hannia'],
       'Edad': [24,24,24,21],
       'Pais': ['Japon', 'Corea', 'Mexico', 'Mexico']}
df = pd.DataFrame(data)
df
# Out:
#    Nombre  Edad    Pais
# 0  Miguel    24   Japon
# 1    Paty    24   Corea
# 2   Cesar    24  Mexico
# 3  Hannia    21  Mexico

# %%
print(df[['Nombre', 'Pais']])
# Out:
#    Nombre    Pais
# 0  Miguel   Japon
# 1    Paty   Corea
# 2   Cesar  Mexico
# 3  Hannia  Mexico

# %%
# Leer un CSV desde pandas y mostrar solo las primeras 5 filas
data = pd.read_csv('.\\documents\\canciones-2018.csv')
data.head(5)
# Out:
#                       id                          name       artists  \
# 0  6DCZcSspjsKoFjzjrWoCd                    God's Plan         Drake
# 1  3ee8Jmje8o58CHK66QrVC                          SAD!  XXXTENTACION
# 2  0e7ipj03S05BNilyu5bRz    rockstar (feat. 21 Savage)   Post Malone
# 3  3swc6WTsr7rl9DqQKQA55  Psycho (feat. Ty Dolla $ign)   Post Malone
# 4  2G7V7zsVDxg1yRsu7Ew9R                In My Feelings         Drake
#
#    danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0         0.754   0.449  7.0    -9.211   1.0       0.1090        0.0332
# 1         0.740   0.613  8.0    -4.880   1.0       0.1450        0.2580
# 2         0.587   0.535  5.0    -6.090   0.0       0.0898        0.1170
# 3         0.739   0.559  8.0    -8.011   1.0       0.1170        0.5800
# 4         0.835   0.626  1.0    -5.833   1.0       0.1250        0.0589
#
#    instrumentalness  liveness  valence    tempo  duration_ms  time_signature
# ...

# %%
# Asignar una columna de data a una variable
artista = data.artists
artista[5]
# Out:
# 'Post Malone'

# %%
# Mostrar informacion por fila de data
info = data.iloc[15]
info
# Out:
# id                     3GCdLUSnKSMJhs4Tj6CV3
# name                All The Stars (with SZA)
# artists                       Kendrick Lamar
# danceability                           0.698
# energy                                 0.633
# key                                        8
# loudness                              -4.946
# mode                                       1
# speechiness                           0.0597
# acousticness                          0.0605
# instrumentalness                    0.000194
# liveness                              0.0926
# valence                                0.552
# tempo                                 96.924
# duration_ms                           232187
# time_signature                             4
# Name: 15, dtype: object

# %%
# Mostrar las ultimas 5 filas de data
data.tail(5)
# Out:
#                        id                               name       artists  \
# 95  630sXRhIcfwr2e4RdNtjK                  Rewrite The Stars     Zac Efron
# 96  2xmrfQpmS2iJExTlklLoA  I Miss You (feat. Julia Michaels)  Clean Bandit
# 97  5WvAo7DNuPRmk4APhdPzi                         No Brainer     DJ Khaled
# 98  1j4kHkkpqZRBwE0A4CN4Y        Dusk Till Dawn - Radio Edit          ZAYN
# 99  3EPXxR3ImUwfayaurPi3c                         Be Alright    Dean Lewis
#
#     danceability  energy   key  loudness  mode  speechiness  acousticness  \
# 95         0.684   0.619  10.0    -7.005   1.0       0.0386        0.0716
# 96         0.638   0.658   3.0    -6.318   1.0       0.0456        0.2450
# 97         0.552   0.760   0.0    -4.706   1.0       0.3420        0.0733
# 98         0.258   0.437  11.0    -6.593   0.0       0.0390        0.1010
# 99         0.553   0.586  11.0    -6.319   1.0       0.0362        0.6970
#
# ...

# %%
# Mostrar la forma de data
data.shape
# Out:
# (100, 16)

# %%
# Columnas de data
data.columns
# Out:
# Index(['id', 'name', 'artists', 'danceability', 'energy', 'key', 'loudness',
#        'mode', 'speechiness', 'acousticness', 'instrumentalness', 'liveness',
#        'valence', 'tempo', 'duration_ms', 'time_signature'],
#       dtype='object')

# %%
# Describir una columna
data['tempo'].describe()
# Out:
# count    100.000000
# mean     119.904180
# std       28.795984
# min       64.934000
# 25%       95.730750
# 50%      120.116000
# 75%      140.022750
# max      198.075000
# Name: tempo, dtype: float64

# %%
# Ordenar de manera descendente
data.sort_index(axis=0, ascending=False)
# Out:
#                        id                                               name  \
# 99  3EPXxR3ImUwfayaurPi3c                                         Be Alright
# 98  1j4kHkkpqZRBwE0A4CN4Y                        Dusk Till Dawn - Radio Edit
# 97  5WvAo7DNuPRmk4APhdPzi                                         No Brainer
# 96  2xmrfQpmS2iJExTlklLoA                  I Miss You (feat. Julia Michaels)
# 95  630sXRhIcfwr2e4RdNtjK                                  Rewrite The Stars
# 94  3GVkPk8mqxz0itaAriG1L                 Everybody Dies In Their Nightmares
# 93  2xGjteMU3E1tkEPVFBO08                                         This Is Me
# 92  2P91MQbaiQOfbiz9VqhqK                                   I Like Me Better
# 91  6vN77lE9LK6HP2DewaN6H                                         Yes Indeed
# 90  5N5k9nd479b1xpDZ4usjr                          Promises (with Sam Smith)
# 89  3xcCix7Jv1Rp90YVmgo35                                              Bella
# ...

# %%
# Ejercicio: Selecciona 3 columnas y ordenalas de manera descendente
subset = data[['name', 'artists', 'duration_ms']]
subset.sort_values(by='name', axis=0, ascending=True)
# Out:
#                                                  name              artists  \
# 77        1, 2, 3 (feat. Jason Derulo & De La Ghetto)          Sofia Reyes
# 60                                               2002           Anne-Marie
# 34                                    ?chame La Culpa           Luis Fonsi
# 15                           All The Stars (with SZA)       Kendrick Lamar
# 47  Back To You - From 13 Reasons Why ? Season 2 S...         Selena Gomez
# 99                                         Be Alright           Dean Lewis
# 54                                           Believer      Imagine Dragons
# 89                                              Bella              Wolfine
# 5                                          Better Now          Post Malone
# 57                                Body (feat. brando)          Loud Luxury
# 49                                   Call Out My Name           The Weeknd
# ...
