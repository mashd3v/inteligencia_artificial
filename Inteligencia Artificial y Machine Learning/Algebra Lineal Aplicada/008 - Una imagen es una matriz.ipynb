# %%
# %matplotlib inline

import numpy as np
import matplotlib.pyplot as plt
from PIL import Image

# %%
plt.style.use('classic')
imagen = Image.open("..\\..\\Imagenes\\iPhone.jpg")
plt.imshow(imagen)

# %%
# Convertir a escala de grises
imagen_gr = imagen.convert('LA')
print(imagen_gr)
# Out:
# <PIL.Image.Image image mode=LA size=450x309 at 0x13E394B5488>

# %%
imagen_mat = np.array(list(imagen_gr.getdata(band=0)), float)
print(imagen_mat)
# Out:
# [146. 145. 143. ... 219. 219. 219.]

# %%
imagen_mat.shape = (imagen_gr.size[1], imagen_gr.size[0])
print(imagen_mat)
# Out:
# [[146. 145. 143. ... 238. 239. 239.]
#  [144. 143. 142. ... 237. 237. 237.]
#  [143. 143. 142. ... 236. 235. 235.]
#  ...
#  [226. 226. 226. ... 233. 233. 233.]
#  [226. 226. 226. ... 227. 227. 227.]
#  [225. 226. 226. ... 219. 219. 219.]]

# %%
print(imagen_mat.shape)
# Out:
# (309, 450)

# %%
#Conversion de array a escala de grises
plt.imshow(imagen_mat, cmap='gray')
plt.show()

# %%
print(np.max(imagen_mat))
print(np.min(imagen_mat))
# Out:
# 254.0
# 2.0
