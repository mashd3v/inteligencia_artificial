# %%
import tensorflow as tf
from tensorflow import keras

# %%
# Cargar conjunto de datos de Tensor Flow:
fashion_mnist = keras.datasets.fashion_mnist
(train_images, train_labels), (test_images, test_labels) = fashion_mnist.load_data()

# %%
# Crear modelo secuencial:
model = keras.Sequential([keras.layers.Flatten(input_shape = (28, 28)), 
                          keras.layers.Dense(128, activation = tf.nn.relu), 
                          keras.layers.Dense(10, activation = tf.nn.softmax)])

# %%
# Compilación del modelo:
model.compile(optimizer = tf.optimizers.Adam(), 
              loss = 'sparse_categorical_crossentropy', 
              metrics = ['accuracy'])

# %%
# Entrenamiento:
model.fit(train_images, train_labels, epochs = 5)
# Out:
# Train on 60000 samples
# Epoch 1/5
# 60000/60000 [==============================] - 3s 44us/sample - loss: 3.6947 - accuracy: 0.6867
# Epoch 2/5
# 60000/60000 [==============================] - 2s 36us/sample - loss: 0.6965 - accuracy: 0.7363
# Epoch 3/5
# 60000/60000 [==============================] - 2s 34us/sample - loss: 0.6002 - accuracy: 0.7861
# Epoch 4/5
# 60000/60000 [==============================] - 2s 34us/sample - loss: 0.5760 - accuracy: 0.7973
# Epoch 5/5
# 60000/60000 [==============================] - 2s 35us/sample - loss: 0.5383 - accuracy: 0.8114

# %%
# Evaluación del modelo:
test_loss, test_acc = model.evaluate(test_images, test_labels)
# Out:
# 10000/1 [======================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================= ...

# %%
# Predicción del modelo:
model.predict(test_images)
# Out:
# array([[6.3063030e-19, 1.1844977e-21, 1.9242605e-34, ..., 2.6603971e-02,
#         7.3348416e-09, 9.1651362e-01],
#        [2.1897307e-04, 2.9209652e-04, 6.3977998e-01, ..., 1.0064020e-26,
#         1.5338719e-07, 1.8942450e-26],
#        [1.3107479e-08, 9.9999881e-01, 2.8714073e-12, ..., 0.0000000e+00,
#         5.6279321e-11, 0.0000000e+00],
#        ...,
#        [2.9392584e-05, 7.1388911e-08, 8.8930137e-06, ..., 2.8666363e-15,
#         9.9306291e-01, 4.9209099e-18],
#        [8.7800863e-08, 9.9974567e-01, 7.6775929e-12, ..., 0.0000000e+00,
#         5.9789400e-08, 0.0000000e+00],
#        [5.0895205e-10, 3.1852883e-28, 2.1801755e-10, ..., 1.1675029e-02,
#         1.5055205e-04, 1.9158570e-03]], dtype=float32)
